# %%
# Import Dependencies
import numpy as np
import pandas as pd
import json

# %%
# Create random latitudes 
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lats_lngs = zip(lats, lngs)

# %%
# Unzip into a list
coordinates = list(lats_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding cities
cities = []
# Identify the nearest city for each lat and lng combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if city is unique, add to list
    if city not in cities:
        cities.append(city)
        
# Print city count to confirm sufficient list
len(cities)
# Out:
# 765

# %%
# Import requests library
import requests 

# Import the API keys
from config import gkey
from config import weather_api_key

# import datetime
from datetime import datetime

# %%
# API requests time
# base URL
url = "http://api.openweathermap.org/data/2.5/weather?q="

# Create empty list for data
city_data = []
# Create Counters
record_count = 1
set_count = 1

# Loop through all cities in the list
for i, city in enumerate(cities):
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
    # Create request URL w/city
    city_url = url + city.replace(" ", "+") + "&units=imperial" + "&appid=" + weather_api_key
    
    # Log URL, print record set and city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    # Run the request!
    try:
        city_weather = requests.get(city_url).json()
        # Needed Data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append city info
        city_data.append({
            "City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_description})
    except:
        print("City not found. Skipping...")
        pass
# When data loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | ostrovnoy
# Processing Record 3 of Set 1 | san patricio
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | bijie
# Processing Record 6 of Set 1 | tuatapere
# Processing Record 7 of Set 1 | aklavik
# Processing Record 8 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | billings
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | ternate
# Processing Record 28 of Set 1 | ahuimanu
# Processing Record 29 of Set 1 | sedan
# Processing Record 30 of Set 1 | merauke
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | bandarbeyla
# Processing Record 33 of Set 1 | saint-pierre
# Processing Record 34 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of Set 1 | bac lieu
# Processing Record 36 of Set 1 | ovria
# Processing Record 37 of Set 1 | alpena
# Processing Record 38 of Set 1 | hambantota
# Processing Record 39 of Set 1 | wexford
# Processing Record 40 of Set 1 | madimba
# Processing Record 41 of Set 1 | kununurra
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | college
# Processing Record 45 of Set 1 | bud
# Processing Record 46 of Set 1 | marrakesh
# Processing Record 47 of Set 1 | morros
# Processing Record 48 of Set 1 | namatanai
# Processing Record 49 of Set 1 | awbari
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 52 of Set 2 | zhaotong
# Processing Record 53 of Set 2 | rikitea
# Processing Record 54 of Set 2 | clyde river
# Processing Record 55 of Set 2 | albanel
# Processing Record 56 of Set 2 | ribeira grande
# Processing Record 57 of Set 2 | puerto ayora
# Processing Record 58 of Set 2 | mogilno
# Processing Record 59 of Set 2 | bagdarin
# Processing Record 60 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 61 of Set 2 | jamestown
# Processing Record 62 of Set 2 | arlit
# Processing Record 63 of Set 2 | boende
# Processing Record 64 of Set 2 | gao
# Processing Record 65 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 66 of Set 2 | hithadhoo
# Processing Record 67 of Set 2 | bluff
# Processing Record 68 of Set 2 | berlevag
# Processing Record 69 of Set 2 | tilichiki
# Processing Record 70 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 71 of Set 2 | dunedin
# Processing Record 72 of Set 2 | new norfolk
# Processing Record 73 of Set 2 | tuktoyaktuk
# Processing Record 74 of Set 2 | sola
# Processing Record 75 of Set 2 | grindavik
# Processing Record 76 of Set 2 | cikupa
# Processing Record 77 of Set 2 | sanandaj
# Processing Record 78 of Set 2 | bathsheba
# Processing Record 79 of Set 2 | torbay
# Processing Record 80 of Set 2 | santa maria
# Processing Record 81 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 82 of Set 2 | ketchikan
# Processing Record 83 of Set 2 | lorengau
# Processing Record 84 of Set 2 | ilulissat
# Processing Record 85 of Set 2 | moose factory
# Processing Record 86 of Set 2 | akureyri
# Processing Record 87 of Set 2 | katsuura
# Processing Record 88 of Set 2 | praia da vitoria
# Processing Record 89 of Set 2 | tecoanapa
# Processing Record 90 of Set 2 | esna
# Processing Record 91 of Set 2 | makaleng
# Processing Record 92 of Set 2 | ulladulla
# Processing Record 93 of Set 2 | kolondieba
# Processing Record 94 of Set 2 | luis correia
# Processing Record 95 of Set 2 | vestmannaeyjar
# Processing Record 96 of Set 2 | mildura
# Processing Record 97 of Set 2 | zeya
# Processing Record 98 of Set 2 | longyearbyen
# Processing Record 99 of Set 2 | hobart
# Processing Record 100 of Set 2 | jagdalpur
# Processing Record 101 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 103 of Set 3 | kalmunai
# Processing Record 104 of Set 3 | coquimbo
# Processing Record 105 of Set 3 | bethel
# Processing Record 106 of Set 3 | olafsvik
# Processing Record 107 of Set 3 | caravelas
# Processing Record 108 of Set 3 | kieta
# Processing Record 109 of Set 3 | khatanga
# Processing Record 110 of Set 3 | adrar
# Processing Record 111 of Set 3 | kaitangata
# Processing Record 112 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 113 of Set 3 | kaduy
# Processing Record 114 of Set 3 | port alfred
# Processing Record 115 of Set 3 | neustadt
# Processing Record 116 of Set 3 | souillac
# Processing Record 117 of Set 3 | butaritari
# Processing Record 118 of Set 3 | san diego
# Processing Record 119 of Set 3 | sanmenxia
# Processing Record 120 of Set 3 | opuwo
# Processing Record 121 of Set 3 | baruun-urt
# Processing Record 122 of Set 3 | yellowknife
# Processing Record 123 of Set 3 | airai
# Processing Record 124 of Set 3 | vardo
# Processing Record 125 of Set 3 | isoka
# Processing Record 126 of Set 3 | elliot lake
# Processing Record 127 of Set 3 | urumqi
# Processing Record 128 of Set 3 | choya
# Processing Record 129 of Set 3 | grand gaube
# Processing Record 130 of Set 3 | port lincoln
# Processing Record 131 of Set 3 | kruisfontein
# Processing Record 132 of Set 3 | severo-kurilsk
# Processing Record 133 of Set 3 | saint-augustin
# Processing Record 134 of Set 3 | kerteh
# City not found. Skipping...
# Processing Record 135 of Set 3 | timon
# Processing Record 136 of Set 3 | gladstone
# Processing Record 137 of Set 3 | zyryanka
# Processing Record 138 of Set 3 | rafaela
# Processing Record 139 of Set 3 | ena
# Processing Record 140 of Set 3 | tiksi
# Processing Record 141 of Set 3 | dharmavaram
# Processing Record 142 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 143 of Set 3 | tacuarembo
# Processing Record 144 of Set 3 | port hedland
# Processing Record 145 of Set 3 | camacha
# Processing Record 146 of Set 3 | castro
# Processing Record 147 of Set 3 | clarence town
# Processing Record 148 of Set 3 | puerto del rosario
# Processing Record 149 of Set 3 | thompson
# Processing Record 150 of Set 3 | yazoo city
# Processing Record 151 of Set 3 | santa fe
# Processing Record 152 of Set 3 | alta floresta
# Processing Record 154 of Set 4 | arraial do cabo
# Processing Record 155 of Set 4 | sept-iles
# Processing Record 156 of Set 4 | upernavik
# Processing Record 157 of Set 4 | luwuk
# Processing Record 158 of Set 4 | fortuna
# Processing Record 159 of Set 4 | sharanga
# Processing Record 160 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 161 of Set 4 | loralai
# Processing Record 162 of Set 4 | champerico
# Processing Record 163 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 164 of Set 4 | saint-gaudens
# Processing Record 165 of Set 4 | pisco
# Processing Record 166 of Set 4 | dunmore town
# Processing Record 167 of Set 4 | hovd
# Processing Record 168 of Set 4 | padang
# Processing Record 169 of Set 4 | waddan
# Processing Record 170 of Set 4 | waipawa
# Processing Record 171 of Set 4 | fort myers beach
# Processing Record 172 of Set 4 | saint george
# Processing Record 173 of Set 4 | nouakchott
# Processing Record 174 of Set 4 | bentiu
# Processing Record 175 of Set 4 | puerto escondido
# Processing Record 176 of Set 4 | ponta do sol
# Processing Record 177 of Set 4 | geraldton
# Processing Record 178 of Set 4 | outlook
# Processing Record 179 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 180 of Set 4 | tasiilaq
# Processing Record 181 of Set 4 | kulhudhuffushi
# Processing Record 182 of Set 4 | arkhipo-osipovka
# Processing Record 183 of Set 4 | coihaique
# Processing Record 184 of Set 4 | sibutad
# Processing Record 185 of Set 4 | berea
# Processing Record 186 of Set 4 | saint anthony
# Processing Record 187 of Set 4 | hualmay
# Processing Record 188 of Set 4 | zhicheng
# Processing Record 189 of Set 4 | chuy
# Processing Record 190 of Set 4 | save
# Processing Record 191 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 192 of Set 4 | nurota
# Processing Record 193 of Set 4 | terra nova
# Processing Record 194 of Set 4 | koprivnica
# Processing Record 195 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 196 of Set 4 | boa vista
# Processing Record 197 of Set 4 | mar del plata
# Processing Record 198 of Set 4 | copiapo
# Processing Record 199 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 200 of Set 4 | abdanan
# Processing Record 201 of Set 4 | esso
# Processing Record 202 of Set 4 | ganzhou
# Processing Record 203 of Set 4 | saint-francois
# Processing Record 205 of Set 5 | mount gambier
# Processing Record 206 of Set 5 | sakakah
# Processing Record 207 of Set 5 | oriximina
# Processing Record 208 of Set 5 | altayskoye
# Processing Record 209 of Set 5 | paamiut
# Processing Record 210 of Set 5 | pontarlier
# Processing Record 211 of Set 5 | port elizabeth
# Processing Record 212 of Set 5 | la palma
# Processing Record 213 of Set 5 | tessalit
# Processing Record 214 of Set 5 | belorechensk
# Processing Record 215 of Set 5 | east london
# Processing Record 216 of Set 5 | bembereke
# Processing Record 217 of Set 5 | dikson
# Processing Record 218 of Set 5 | komsomolskiy
# Processing Record 219 of Set 5 | srednekolymsk
# Processing Record 220 of Set 5 | korgen
# Processing Record 221 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 222 of Set 5 | tamandare
# Processing Record 223 of Set 5 | broken hill
# Processing Record 224 of Set 5 | port augusta
# Processing Record 225 of Set 5 | tecpatan
# Processing Record 226 of Set 5 | broome
# Processing Record 227 of Set 5 | charters towers
# Processing Record 228 of Set 5 | pevek
# Processing Record 229 of Set 5 | ballina
# Processing Record 230 of Set 5 | manta
# Processing Record 231 of Set 5 | itarema
# Processing Record 232 of Set 5 | leshukonskoye
# Processing Record 233 of Set 5 | roald
# Processing Record 234 of Set 5 | dong xoai
# Processing Record 235 of Set 5 | canutama
# Processing Record 236 of Set 5 | kodiak
# Processing Record 237 of Set 5 | tumut
# Processing Record 238 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 239 of Set 5 | flinders
# Processing Record 240 of Set 5 | lompoc
# Processing Record 241 of Set 5 | cabo san lucas
# Processing Record 242 of Set 5 | isangel
# Processing Record 243 of Set 5 | chaman
# Processing Record 244 of Set 5 | leh
# Processing Record 245 of Set 5 | khorramshahr
# Processing Record 246 of Set 5 | iqaluit
# Processing Record 247 of Set 5 | pandan
# Processing Record 248 of Set 5 | magdagachi
# Processing Record 249 of Set 5 | benguela
# Processing Record 250 of Set 5 | saldanha
# Processing Record 251 of Set 5 | sioux lookout
# Processing Record 252 of Set 5 | cockburn town
# Processing Record 253 of Set 5 | cherskiy
# Processing Record 254 of Set 5 | ixtapa
# Processing Record 256 of Set 6 | norman wells
# Processing Record 257 of Set 6 | safaga
# Processing Record 258 of Set 6 | anadyr
# Processing Record 259 of Set 6 | kaspiysk
# Processing Record 260 of Set 6 | elmadag
# Processing Record 261 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 262 of Set 6 | fujin
# Processing Record 263 of Set 6 | skelleftea
# Processing Record 264 of Set 6 | esperance
# Processing Record 265 of Set 6 | homer
# Processing Record 266 of Set 6 | verkhoyansk
# Processing Record 267 of Set 6 | whitefish
# Processing Record 268 of Set 6 | luderitz
# Processing Record 269 of Set 6 | xichang
# Processing Record 270 of Set 6 | touros
# Processing Record 271 of Set 6 | cabedelo
# Processing Record 272 of Set 6 | sao luiz gonzaga
# Processing Record 273 of Set 6 | freeport
# Processing Record 274 of Set 6 | nanortalik
# Processing Record 275 of Set 6 | burns lake
# Processing Record 276 of Set 6 | sao joao da barra
# Processing Record 277 of Set 6 | killybegs
# Processing Record 278 of Set 6 | dongfeng
# Processing Record 279 of Set 6 | cayenne
# Processing Record 280 of Set 6 | ciro marina
# Processing Record 281 of Set 6 | bireun
# Processing Record 282 of Set 6 | si bun ruang
# Processing Record 283 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 284 of Set 6 | menongue
# Processing Record 285 of Set 6 | pathein
# Processing Record 286 of Set 6 | presidencia roque saenz pena
# Processing Record 287 of Set 6 | samarai
# Processing Record 288 of Set 6 | sokol
# Processing Record 289 of Set 6 | morrope
# Processing Record 290 of Set 6 | olinda
# Processing Record 291 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 292 of Set 6 | umm lajj
# Processing Record 293 of Set 6 | sitka
# Processing Record 294 of Set 6 | puksoozero
# Processing Record 295 of Set 6 | carauari
# Processing Record 296 of Set 6 | innisfail
# Processing Record 297 of Set 6 | emilio carranza
# Processing Record 298 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 299 of Set 6 | guderup
# Processing Record 300 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 301 of Set 6 | kundiawa
# Processing Record 302 of Set 6 | paz de ariporo
# City not found. Skipping...
# Processing Record 303 of Set 6 | hjelset
# Processing Record 304 of Set 6 | nikki
# Processing Record 305 of Set 6 | umtata
# Processing Record 307 of Set 7 | yuli
# Processing Record 308 of Set 7 | ahipara
# Processing Record 309 of Set 7 | inhambane
# Processing Record 310 of Set 7 | kahului
# Processing Record 311 of Set 7 | lasa
# Processing Record 312 of Set 7 | saint-paul
# Processing Record 313 of Set 7 | chokurdakh
# Processing Record 314 of Set 7 | benjamin hill
# Processing Record 315 of Set 7 | beringovskiy
# Processing Record 316 of Set 7 | mto wa mbu
# Processing Record 317 of Set 7 | fort nelson
# Processing Record 318 of Set 7 | san cristobal
# Processing Record 319 of Set 7 | pangnirtung
# Processing Record 320 of Set 7 | udachnyy
# Processing Record 321 of Set 7 | ancud
# Processing Record 322 of Set 7 | provideniya
# Processing Record 323 of Set 7 | husavik
# Processing Record 324 of Set 7 | dwarka
# Processing Record 325 of Set 7 | marzuq
# Processing Record 326 of Set 7 | cartagena
# Processing Record 327 of Set 7 | te anau
# Processing Record 328 of Set 7 | whitehorse
# Processing Record 329 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 330 of Set 7 | nizhnevartovsk
# Processing Record 331 of Set 7 | faanui
# Processing Record 332 of Set 7 | rio grande
# Processing Record 333 of Set 7 | salalah
# Processing Record 334 of Set 7 | guerrero negro
# Processing Record 335 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 336 of Set 7 | aksu
# Processing Record 337 of Set 7 | xiaoyi
# Processing Record 338 of Set 7 | nortelandia
# Processing Record 339 of Set 7 | cidreira
# Processing Record 340 of Set 7 | aksarka
# Processing Record 341 of Set 7 | coruripe
# Processing Record 342 of Set 7 | san ramon
# Processing Record 343 of Set 7 | hasaki
# Processing Record 344 of Set 7 | port hueneme
# Processing Record 345 of Set 7 | vila velha
# Processing Record 346 of Set 7 | saskylakh
# Processing Record 347 of Set 7 | shimoda
# Processing Record 348 of Set 7 | malakal
# Processing Record 349 of Set 7 | itoman
# Processing Record 350 of Set 7 | nova ushytsya
# Processing Record 351 of Set 7 | nagato
# Processing Record 352 of Set 7 | westport
# Processing Record 353 of Set 7 | wattegama
# Processing Record 354 of Set 7 | najran
# Processing Record 355 of Set 7 | port blair
# Processing Record 356 of Set 7 | klaksvik
# Processing Record 358 of Set 8 | phangnga
# Processing Record 359 of Set 8 | leningradskiy
# Processing Record 360 of Set 8 | comodoro rivadavia
# Processing Record 361 of Set 8 | poya
# Processing Record 362 of Set 8 | codrington
# Processing Record 363 of Set 8 | daru
# Processing Record 364 of Set 8 | constitucion
# Processing Record 365 of Set 8 | lavrentiya
# Processing Record 366 of Set 8 | kenai
# Processing Record 367 of Set 8 | korla
# Processing Record 368 of Set 8 | deputatskiy
# Processing Record 369 of Set 8 | amuntai
# Processing Record 370 of Set 8 | wanlaweyn
# Processing Record 371 of Set 8 | kirakira
# Processing Record 372 of Set 8 | dakar
# Processing Record 373 of Set 8 | meadow lake
# Processing Record 374 of Set 8 | bengkulu
# Processing Record 375 of Set 8 | viedma
# Processing Record 376 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 377 of Set 8 | black river
# Processing Record 378 of Set 8 | santa cruz
# Processing Record 379 of Set 8 | kyren
# Processing Record 380 of Set 8 | la ronge
# Processing Record 381 of Set 8 | mitsamiouli
# Processing Record 382 of Set 8 | narsaq
# Processing Record 383 of Set 8 | sabzevar
# Processing Record 384 of Set 8 | antalaha
# Processing Record 385 of Set 8 | gat
# Processing Record 386 of Set 8 | ginir
# Processing Record 387 of Set 8 | okhotsk
# Processing Record 388 of Set 8 | huazolotitlan
# City not found. Skipping...
# Processing Record 389 of Set 8 | vallenar
# Processing Record 390 of Set 8 | kokopo
# Processing Record 391 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 392 of Set 8 | victoria
# Processing Record 393 of Set 8 | bairiki
# Processing Record 394 of Set 8 | tavda
# Processing Record 395 of Set 8 | borama
# City not found. Skipping...
# Processing Record 396 of Set 8 | muros
# Processing Record 397 of Set 8 | liverpool
# Processing Record 398 of Set 8 | sao gabriel da cachoeira
# Processing Record 399 of Set 8 | north bend
# Processing Record 400 of Set 8 | amapa
# Processing Record 401 of Set 8 | jimma
# Processing Record 402 of Set 8 | nizhniy kuranakh
# Processing Record 403 of Set 8 | krasnogorsk
# Processing Record 404 of Set 8 | kayerkan
# Processing Record 405 of Set 8 | tucuma
# Processing Record 406 of Set 8 | bonavista
# Processing Record 407 of Set 8 | kuloy
# Processing Record 409 of Set 9 | kavieng
# Processing Record 410 of Set 9 | kabinda
# Processing Record 411 of Set 9 | manjacaze
# Processing Record 412 of Set 9 | namibe
# Processing Record 413 of Set 9 | gorom-gorom
# Processing Record 414 of Set 9 | santa isabel do rio negro
# Processing Record 415 of Set 9 | nemuro
# Processing Record 416 of Set 9 | sangar
# Processing Record 417 of Set 9 | tigil
# Processing Record 418 of Set 9 | goderich
# Processing Record 419 of Set 9 | vyshestebliyevskaya
# Processing Record 420 of Set 9 | clearwater
# Processing Record 421 of Set 9 | praya
# Processing Record 422 of Set 9 | tabas
# Processing Record 423 of Set 9 | puerto baquerizo moreno
# Processing Record 424 of Set 9 | kayes
# Processing Record 425 of Set 9 | sao filipe
# Processing Record 426 of Set 9 | atar
# Processing Record 427 of Set 9 | kargasok
# Processing Record 428 of Set 9 | mandiana
# Processing Record 429 of Set 9 | kirkconnel
# Processing Record 430 of Set 9 | port macquarie
# Processing Record 431 of Set 9 | varhaug
# Processing Record 432 of Set 9 | san martin de las piramides
# Processing Record 433 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 434 of Set 9 | isiro
# Processing Record 435 of Set 9 | quatre cocos
# Processing Record 436 of Set 9 | high level
# Processing Record 437 of Set 9 | chifeng
# Processing Record 438 of Set 9 | micheweni
# Processing Record 439 of Set 9 | aquiraz
# Processing Record 440 of Set 9 | mikuni
# Processing Record 441 of Set 9 | porto walter
# Processing Record 442 of Set 9 | chongwe
# Processing Record 443 of Set 9 | alice springs
# Processing Record 444 of Set 9 | chaoyang
# Processing Record 445 of Set 9 | harper
# Processing Record 446 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 447 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 448 of Set 9 | haines junction
# Processing Record 449 of Set 9 | dalby
# Processing Record 450 of Set 9 | esqueda
# Processing Record 451 of Set 9 | west bay
# Processing Record 452 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 453 of Set 9 | tanete
# Processing Record 454 of Set 9 | pinega
# Processing Record 455 of Set 9 | talnakh
# Processing Record 456 of Set 9 | gwadar
# Processing Record 457 of Set 9 | dire
# Processing Record 458 of Set 9 | ugljevik
# Processing Record 460 of Set 10 | asyut
# Processing Record 461 of Set 10 | la asuncion
# Processing Record 462 of Set 10 | tautira
# Processing Record 463 of Set 10 | svetlaya
# Processing Record 464 of Set 10 | bulgan
# Processing Record 465 of Set 10 | maragogi
# Processing Record 466 of Set 10 | trairi
# Processing Record 467 of Set 10 | wanning
# Processing Record 468 of Set 10 | sinnamary
# Processing Record 469 of Set 10 | nicoya
# Processing Record 470 of Set 10 | acapulco
# Processing Record 471 of Set 10 | ormara
# Processing Record 472 of Set 10 | puerto carreno
# Processing Record 473 of Set 10 | sao miguel do araguaia
# Processing Record 474 of Set 10 | tayoltita
# Processing Record 475 of Set 10 | manado
# Processing Record 476 of Set 10 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 477 of Set 10 | nioro
# Processing Record 478 of Set 10 | jiazi
# Processing Record 479 of Set 10 | eston
# Processing Record 480 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 481 of Set 10 | lodwar
# Processing Record 482 of Set 10 | praia
# Processing Record 483 of Set 10 | ulaanbaatar
# Processing Record 484 of Set 10 | shitanjing
# Processing Record 485 of Set 10 | iskilip
# Processing Record 486 of Set 10 | iberia
# Processing Record 487 of Set 10 | sidrolandia
# Processing Record 488 of Set 10 | puerto madryn
# Processing Record 489 of Set 10 | luganville
# Processing Record 490 of Set 10 | bagru
# Processing Record 491 of Set 10 | ambon
# Processing Record 492 of Set 10 | greenwood
# Processing Record 493 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 494 of Set 10 | port hardy
# Processing Record 495 of Set 10 | hong gai
# Processing Record 496 of Set 10 | aleksandrovskoye
# Processing Record 497 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 498 of Set 10 | vostok
# Processing Record 499 of Set 10 | kenora
# Processing Record 500 of Set 10 | taoudenni
# Processing Record 501 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 502 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 503 of Set 10 | candelaria
# Processing Record 504 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 505 of Set 10 | paita
# Processing Record 506 of Set 10 | hamilton
# Processing Record 507 of Set 10 | kilindoni
# Processing Record 508 of Set 10 | mahibadhoo
# Processing Record 509 of Set 10 | brae
# Processing Record 511 of Set 11 | moron
# Processing Record 512 of Set 11 | ayabe
# Processing Record 513 of Set 11 | natalio
# Processing Record 514 of Set 11 | anahuac
# Processing Record 515 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 516 of Set 11 | bilibino
# Processing Record 517 of Set 11 | bani walid
# Processing Record 518 of Set 11 | tiruvottiyur
# City not found. Skipping...
# Processing Record 519 of Set 11 | andijon
# Processing Record 520 of Set 11 | soe
# Processing Record 521 of Set 11 | carutapera
# Processing Record 522 of Set 11 | paeroa
# Processing Record 523 of Set 11 | muyuka
# Processing Record 524 of Set 11 | katrineholm
# Processing Record 525 of Set 11 | gillette
# Processing Record 526 of Set 11 | novyy yegorlyk
# Processing Record 527 of Set 11 | solwezi
# Processing Record 528 of Set 11 | marawi
# Processing Record 529 of Set 11 | shaunavon
# Processing Record 530 of Set 11 | francisco sa
# Processing Record 531 of Set 11 | ukiah
# Processing Record 532 of Set 11 | nuuk
# Processing Record 533 of Set 11 | tual
# Processing Record 534 of Set 11 | araouane
# Processing Record 535 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 536 of Set 11 | riyadh
# Processing Record 537 of Set 11 | urengoy
# Processing Record 538 of Set 11 | ponta delgada
# Processing Record 539 of Set 11 | yibin
# Processing Record 540 of Set 11 | mwanza
# Processing Record 541 of Set 11 | goksun
# Processing Record 542 of Set 11 | vila do maio
# Processing Record 543 of Set 11 | cairns
# Processing Record 544 of Set 11 | odweyne
# Processing Record 545 of Set 11 | yurgamysh
# Processing Record 546 of Set 11 | kavaratti
# Processing Record 547 of Set 11 | iskateley
# Processing Record 548 of Set 11 | kapit
# Processing Record 549 of Set 11 | maarianhamina
# Processing Record 550 of Set 11 | rimini
# Processing Record 551 of Set 11 | taft
# Processing Record 552 of Set 11 | qaqortoq
# Processing Record 553 of Set 11 | chilliwack
# Processing Record 554 of Set 11 | takoradi
# Processing Record 555 of Set 11 | kamaishi
# Processing Record 556 of Set 11 | kanodar
# Processing Record 557 of Set 11 | tenenkou
# Processing Record 558 of Set 11 | panjab
# Processing Record 559 of Set 11 | voyvozh
# Processing Record 560 of Set 11 | sorong
# Processing Record 562 of Set 12 | sandwick
# Processing Record 563 of Set 12 | san juan ixcoy
# Processing Record 564 of Set 12 | bilma
# Processing Record 565 of Set 12 | bubaque
# Processing Record 566 of Set 12 | coxim
# Processing Record 567 of Set 12 | puerto penasco
# Processing Record 568 of Set 12 | nizwa
# Processing Record 569 of Set 12 | dudinka
# Processing Record 570 of Set 12 | marsa matruh
# Processing Record 571 of Set 12 | taitung
# Processing Record 572 of Set 12 | baker city
# Processing Record 573 of Set 12 | urdoma
# Processing Record 574 of Set 12 | uri
# Processing Record 575 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 576 of Set 12 | hengyang
# Processing Record 577 of Set 12 | baie-comeau
# Processing Record 578 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 579 of Set 12 | severnyy
# Processing Record 580 of Set 12 | oksfjord
# Processing Record 581 of Set 12 | elko
# Processing Record 582 of Set 12 | khonsa
# Processing Record 583 of Set 12 | svetlogorsk
# Processing Record 584 of Set 12 | leninsk
# Processing Record 585 of Set 12 | guadalupe y calvo
# Processing Record 586 of Set 12 | zhangjiakou
# Processing Record 587 of Set 12 | zhigansk
# Processing Record 588 of Set 12 | lar
# Processing Record 589 of Set 12 | xining
# Processing Record 590 of Set 12 | altay
# Processing Record 591 of Set 12 | tres arroyos
# Processing Record 592 of Set 12 | cilegon
# Processing Record 593 of Set 12 | gushikawa
# Processing Record 594 of Set 12 | sao jose da coroa grande
# Processing Record 595 of Set 12 | bonthe
# Processing Record 596 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 597 of Set 12 | shahreza
# Processing Record 598 of Set 12 | zonguldak
# Processing Record 599 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 600 of Set 12 | lindi
# Processing Record 601 of Set 12 | pemangkat
# Processing Record 602 of Set 12 | kudahuvadhoo
# Processing Record 603 of Set 12 | cienfuegos
# Processing Record 604 of Set 12 | xuddur
# Processing Record 605 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 606 of Set 12 | shingu
# Processing Record 607 of Set 12 | faya
# Processing Record 608 of Set 12 | jarjis
# City not found. Skipping...
# Processing Record 609 of Set 12 | nzega
# Processing Record 610 of Set 12 | lobito
# Processing Record 611 of Set 12 | vega de alatorre
# Processing Record 613 of Set 13 | huarmey
# Processing Record 614 of Set 13 | kloulklubed
# Processing Record 615 of Set 13 | sur
# Processing Record 616 of Set 13 | tres lagoas
# Processing Record 617 of Set 13 | bahia honda
# Processing Record 618 of Set 13 | neryungri
# Processing Record 619 of Set 13 | kuito
# Processing Record 620 of Set 13 | ciempozuelos
# Processing Record 621 of Set 13 | san joaquin
# Processing Record 622 of Set 13 | vao
# Processing Record 623 of Set 13 | rawson
# Processing Record 624 of Set 13 | jiexiu
# Processing Record 625 of Set 13 | shima
# Processing Record 626 of Set 13 | ilebo
# Processing Record 627 of Set 13 | eching
# Processing Record 628 of Set 13 | hami
# Processing Record 629 of Set 13 | camana
# Processing Record 630 of Set 13 | goundam
# Processing Record 631 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 632 of Set 13 | dingle
# Processing Record 633 of Set 13 | kirkwall
# Processing Record 634 of Set 13 | xunchang
# Processing Record 635 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 636 of Set 13 | inirida
# Processing Record 637 of Set 13 | mount isa
# Processing Record 638 of Set 13 | asau
# Processing Record 639 of Set 13 | ouidah
# Processing Record 640 of Set 13 | khash
# Processing Record 641 of Set 13 | stornoway
# Processing Record 642 of Set 13 | euclides da cunha
# Processing Record 643 of Set 13 | tarko-sale
# Processing Record 644 of Set 13 | nome
# Processing Record 645 of Set 13 | snihurivka
# Processing Record 646 of Set 13 | chebenki
# Processing Record 647 of Set 13 | shu
# Processing Record 648 of Set 13 | burhanpur
# Processing Record 649 of Set 13 | zhezkazgan
# Processing Record 650 of Set 13 | baghmara
# Processing Record 651 of Set 13 | marand
# Processing Record 652 of Set 13 | richards bay
# Processing Record 653 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 654 of Set 13 | kamenka
# Processing Record 655 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 656 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 657 of Set 13 | taltal
# Processing Record 658 of Set 13 | kambarka
# Processing Record 659 of Set 13 | remontnoye
# Processing Record 660 of Set 13 | moses lake
# Processing Record 661 of Set 13 | portland
# Processing Record 662 of Set 13 | kupang
# Processing Record 664 of Set 14 | raga
# Processing Record 665 of Set 14 | fairbanks
# Processing Record 666 of Set 14 | katunino
# Processing Record 667 of Set 14 | malinovoye ozero
# Processing Record 668 of Set 14 | biak
# Processing Record 669 of Set 14 | belmonte
# Processing Record 670 of Set 14 | dalinghe
# City not found. Skipping...
# Processing Record 671 of Set 14 | sao joao do paraiso
# Processing Record 672 of Set 14 | dandong
# Processing Record 673 of Set 14 | tabuk
# Processing Record 674 of Set 14 | manyana
# Processing Record 675 of Set 14 | slamannan
# Processing Record 676 of Set 14 | christchurch
# Processing Record 677 of Set 14 | mecca
# Processing Record 678 of Set 14 | margate
# Processing Record 679 of Set 14 | bowen
# Processing Record 680 of Set 14 | kotra
# Processing Record 681 of Set 14 | atasu
# Processing Record 682 of Set 14 | ust-omchug
# Processing Record 683 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 684 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 685 of Set 14 | mehran
# Processing Record 686 of Set 14 | laguna
# Processing Record 687 of Set 14 | abonnema
# Processing Record 688 of Set 14 | beruwala
# Processing Record 689 of Set 14 | gisborne
# Processing Record 690 of Set 14 | santa marta
# Processing Record 691 of Set 14 | avera
# Processing Record 692 of Set 14 | tamworth
# Processing Record 693 of Set 14 | basco
# Processing Record 694 of Set 14 | punta gorda
# Processing Record 695 of Set 14 | torres
# Processing Record 696 of Set 14 | vadso
# Processing Record 697 of Set 14 | llanes
# Processing Record 698 of Set 14 | jizan
# Processing Record 699 of Set 14 | loyga
# Processing Record 700 of Set 14 | tateyama
# Processing Record 701 of Set 14 | denizli
# Processing Record 702 of Set 14 | beyneu
# Processing Record 703 of Set 14 | asuncion
# Processing Record 704 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 705 of Set 14 | neiafu
# Processing Record 706 of Set 14 | yalchiki
# City not found. Skipping...
# Processing Record 707 of Set 14 | vung tau
# Processing Record 708 of Set 14 | eydhafushi
# Processing Record 709 of Set 14 | pokhara
# Processing Record 710 of Set 14 | alexandria
# Processing Record 711 of Set 14 | alyangula
# Processing Record 712 of Set 14 | barra
# Processing Record 713 of Set 14 | lumeje
# Processing Record 715 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 716 of Set 15 | eyl
# Processing Record 717 of Set 15 | dukat
# Processing Record 718 of Set 15 | lukovetskiy
# Processing Record 719 of Set 15 | cuamba
# Processing Record 720 of Set 15 | casino
# Processing Record 721 of Set 15 | hokitika
# Processing Record 722 of Set 15 | channel-port aux basques
# Processing Record 723 of Set 15 | moerai
# Processing Record 724 of Set 15 | newcastle
# Processing Record 725 of Set 15 | nabire
# Processing Record 726 of Set 15 | marsh harbour
# Processing Record 727 of Set 15 | wilmington
# Processing Record 728 of Set 15 | marquette
# Processing Record 729 of Set 15 | hecun
# Processing Record 730 of Set 15 | cap malheureux
# Processing Record 731 of Set 15 | mansa
# Processing Record 732 of Set 15 | obluche
# City not found. Skipping...
# Processing Record 733 of Set 15 | new bedford
# Processing Record 734 of Set 15 | carroll
# Processing Record 735 of Set 15 | betioky
# Processing Record 736 of Set 15 | roma
# Processing Record 737 of Set 15 | gloversville
# Processing Record 738 of Set 15 | san quintin
# Processing Record 739 of Set 15 | hofn
# Processing Record 740 of Set 15 | tetiz
# Processing Record 741 of Set 15 | mayor pablo lagerenza
# Processing Record 742 of Set 15 | vestmanna
# Processing Record 743 of Set 15 | polovinnoye
# Processing Record 744 of Set 15 | aitape
# Processing Record 745 of Set 15 | mwinilunga
# Processing Record 746 of Set 15 | zunyi
# Processing Record 747 of Set 15 | karratha
# Processing Record 748 of Set 15 | buchanan
# Processing Record 749 of Set 15 | vrangel
# Processing Record 750 of Set 15 | boa viagem
# Processing Record 751 of Set 15 | zhob
# Processing Record 752 of Set 15 | tezu
# Processing Record 753 of Set 15 | half moon bay
# Processing Record 754 of Set 15 | otane
# Processing Record 755 of Set 15 | foumban
# Processing Record 756 of Set 15 | arima
# Processing Record 757 of Set 15 | rupert
# Processing Record 758 of Set 15 | alzey
# Processing Record 759 of Set 15 | nyagan
# Processing Record 760 of Set 15 | ponta grossa
# Processing Record 761 of Set 15 | paso de los toros
# Processing Record 762 of Set 15 | omsukchan
# Processing Record 763 of Set 15 | waingapu
# Processing Record 764 of Set 15 | wangaratta
# Processing Record 766 of Set 16 | beinamar
# Processing Record 767 of Set 16 | paso de patria
# Processing Record 768 of Set 16 | garden city
# Processing Record 769 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 770 of Set 16 | galiwinku
# City not found. Skipping...
# Processing Record 771 of Set 16 | crab hill
# City not found. Skipping...
# Processing Record 772 of Set 16 | shubarkuduk
# Processing Record 773 of Set 16 | kaeo
# Processing Record 774 of Set 16 | kandi
# Processing Record 775 of Set 16 | tignere
# Processing Record 776 of Set 16 | coeneo
# Processing Record 777 of Set 16 | curup
# Processing Record 778 of Set 16 | alice town
# Processing Record 779 of Set 16 | bambari
# Processing Record 780 of Set 16 | isabela
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the data dictionaries to Data Frame
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura -46.1927  168.8643     42.01        83         100
# 1     Ostrovnoy  68.0531   39.5131     24.62        84         100
# 2  San Patricio  28.0170  -97.5169     82.00        83          90
# 3        Avarua -21.2078 -159.7750     77.00        94          97
# 4         Bijie  27.3125  105.2942     56.62        93         100
# 5     Tuatapere -46.1333  167.6833     42.01        83         100
# 6       Aklavik  68.2191 -135.0107     21.20        38           0
# 7    Nikolskoye  59.7035   30.7861     37.40        65          75
# 8          Hilo  19.7297 -155.0900     75.20        60           1
# 9        Barrow  71.2906 -156.7887     19.40        79          90
#
#    Wind Speed Country Current Description
# 0        5.99      NZ     overcast clouds
# 1        6.78      RU     overcast clouds
# 2       13.80      US     overcast clouds
# 3        4.61      CK     overcast clouds
# 4        2.98      CN     overcast clouds
# 5        5.99      NZ     overcast clouds
# 6        6.91      CA           clear sky
# 7        6.71      RU       broken clouds
# 8        6.38      US           clear sky
# 9        8.05      US     overcast clouds

# %%
# Export this dataframe to a csv
output_data = "WeatherPy_Database.csv"

city_data_df.to_csv(output_data, index_label="City ID")
